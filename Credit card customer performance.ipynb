# %% [markdown]
# ### Checking the credit card customer performance with the bank
# #### A. Overview
# Dataset 2 is a list bank customers who have a credit card with the bank. It suggests whether a credit card customer is performing good or bad for a bank. It contains 20 features including demographic, socio-economic and transactional variables for 5050 customers who have an active credit card with the bank.
#
# Data description: The data contains a 'class' variable where bad=Customers who are not profitable credit card holders for the bank and Good=Customers who are profitable credit card holders for the bank. Customer_id is a unique serial number/identifier of each customer

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('credit card customer data.csv')
df.head(5)
# Out:
#    Customer_id checking_status  duration                  credit_history  \
# 0            1              <0        19  critical/other existing credit
# 1            2              <0        60                   existing paid
# 2            3              <0        72  critical/other existing credit
# 3            4              <0        55                   existing paid
# 4            5              <0        67              delayed previously
#
#     purpose  credit_amount savings_status  employment  installment_commitment  \
# 0  business            640           <100  unemployed                       1
# 1  business            903           <100      1<=X<4                       2
# 2  business            523           <100      1<=X<4                       2
# 3  business            605           <100      4<=X<7                       2
# 4  business            709           <100      1<=X<4                       2
#
# ...

# %% [markdown]
# ##### 1) Examine each variable (except customer_id), summarize the finding and interpret them.

# %%
df.iloc[:,1:].describe()
# Out:
#           duration  credit_amount  installment_commitment  residence_since  \
# count  5050.000000    5050.000000             5050.000000      5050.000000
# mean     34.799406    6245.153663                2.587921         2.549505
# std      19.852475    5651.082825                1.138416         1.119351
# min       4.000000     250.000000                1.000000         1.000000
# 25%      18.000000     955.250000                2.000000         2.000000
# 50%      33.000000    4277.500000                3.000000         3.000000
# 75%      51.000000   10866.000000                4.000000         4.000000
# max      72.000000   18424.000000                4.000000         4.000000
#
#                age  bureau_score  num_dependents  Spend_debit_card
# count  5050.000000   5050.000000     5050.000000       5050.000000
# mean     44.785545    200.471287        6.239208       2507.577624
# std      16.413567    155.330759        4.427874       1462.481192
# ...

# %% [markdown]
# #### 2)  Checking the outliers using BoxPlot

# %%
def boxplot(cols,len1):
    plt.figure(1 , figsize = (25,5))
    n = 0
    for i in cols:
        n +=1
        plt.subplot(1,len1,n)
        plt.subplots_adjust(hspace=0.5, wspace=0.5)
        plt.title('Boxplot of {0}'.format(i))
        sns.boxplot(df[i])
    plt.show()

# %%
length = 3
boxplot(['Customer_id','duration','credit_amount'],length)
boxplot(['installment_commitment','residence_since','age'],length)
boxplot(['bureau_score','num_dependents','Spend_debit_card'],length)

# %%
def distplot(cols,len1):
    plt.figure(2 , figsize = (25,5))
    n = 0
    for i in cols:
        n +=1
        plt.subplot(1,len1,n)
        plt.subplots_adjust(hspace=0.5, wspace=0.5)
        plt.title('Distplot of {0}'.format(i))
        sns.distplot(df[i],bins=10)
    plt.show()

# %%
length = 3
distplot(['Customer_id','duration','credit_amount'],length)
distplot(['installment_commitment','residence_since','age'],length)
distplot(['bureau_score','num_dependents','Spend_debit_card'],length)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_18364\32558670.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i],bins=10)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_18364\32558670.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i],bins=10)
# ...

# %% [markdown]
# #### Null Values

# %%
df.isnull().sum()
# Out:
# Customer_id               0
# checking_status           0
# duration                  0
# credit_history            0
# purpose                   0
# credit_amount             0
# savings_status            0
# employment                0
# installment_commitment    0
# personal_status           0
# other_parties             0
# residence_since           0
# property_magnitude        0
# age                       0
# other_payment_plans       0
# housing                   0
# bureau_score              0
# job                       0
# num_dependents            0
# own_telephone             0
# foreign_worker            0
# Spend_debit_card          0
# class                     0
# dtype: int64

# %% [markdown]
# #### Here we are distributing the customers by the age groups

# %%
def age_distribution():
    min_age = df['age'].min()
    age_18_25 = df.age[(df.age >=min_age) & (df.age<=25)]
    age_26_40 = df.age[(df.age >=26) & (df.age<=40)]
    age_41_55 = df.age[(df.age >=41) & (df.age<=55)]
    age_56_65 = df.age[(df.age >=56) & (df.age<=65)]
    age_66_above = df.age[(df.age >=66)]
    
    age_diff = ["18-25","26-40","41-55","56-65","65+"]
    total_Cust = [len(age_18_25),len(age_26_40),len(age_41_55),len(age_56_65),len(age_66_above)]

    return age_diff,total_Cust

# %%
agex,agey = age_distribution()
plt.figure(figsize=(15,6))
sns.barplot(x=agex,y=agey)
plt.title(' Number of customer and ages ')
plt.xlabel('Age')
plt.ylabel('Number of Customer')
plt.show()

# %% [markdown]
# #### Using heatmap we are trying to show the correlation

# %%
corr = df[['Customer_id','duration','credit_amount','installment_commitment','residence_since','age','bureau_score','num_dependents','Spend_debit_card']].corr()
plt.figure(figsize=(20,8))
sns.heatmap(corr,annot=True,cmap='coolwarm')
plt.show()

# %% [markdown]
# #### Develop a logistic regression or Random Forest model to estimate the relationship between 'class' and the other variables. Suggest variables which are more important.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5050 entries, 0 to 5049
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer_id             5050 non-null   int64
#  1   checking_status         5050 non-null   object
#  2   duration                5050 non-null   int64
#  3   credit_history          5050 non-null   object
#  4   purpose                 5050 non-null   object
#  5   credit_amount           5050 non-null   int64
#  6   savings_status          5050 non-null   object
#  7   employment              5050 non-null   object
#  8   installment_commitment  5050 non-null   int64
#  9   personal_status         5050 non-null   object
#  10  other_parties           5050 non-null   object
#  11  residence_since         5050 non-null   int64
#  12  property_magnitude      5050 non-null   object
#  13  age                     5050 non-null   int64
# ...

# %%
df['other_payment_plans'] = df['other_payment_plans'].map({'none':'0','stores':'1','bank':'2'})
df['housing'] = df['housing'].map({'for free':'0','own':'1','rent':'2'})
df['own_telephone'] = df['own_telephone'].map({'none':'0','yes':'1'})
df['foreign_worker'] = df['foreign_worker'].map({'no':'0','yes':'1'})
df['class'] = df['class'].map({'bad':'0','good':'1'})
df.head(10)
# Out:
#    Customer_id checking_status  duration                  credit_history  \
# 0            1              <0        19  critical/other existing credit
# 1            2              <0        60                   existing paid
# 2            3              <0        72  critical/other existing credit
# 3            4              <0        55                   existing paid
# 4            5              <0        67              delayed previously
# 5            6              <0        50  critical/other existing credit
# 6            7              <0        54  critical/other existing credit
# 7            8              <0        17                   existing paid
# 8            9              <0        19                   existing paid
# 9           10              <0        33                   existing paid
#
#     purpose  credit_amount savings_status  employment  installment_commitment  \
# 0  business            640           <100  unemployed                       1
# ...

# %%
df['other_payment_plans'] = df['other_payment_plans'].astype(int)
df['housing'] = df['housing'].astype(int)
df['own_telephone'] = df['own_telephone'].astype(int)
df['foreign_worker'] = df['foreign_worker'].astype(int)
df['class'] = df['class'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5050 entries, 0 to 5049
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer_id             5050 non-null   int64
#  1   checking_status         5050 non-null   object
#  2   duration                5050 non-null   int64
#  3   credit_history          5050 non-null   object
#  4   purpose                 5050 non-null   object
#  5   credit_amount           5050 non-null   int64
#  6   savings_status          5050 non-null   object
#  7   employment              5050 non-null   object
#  8   installment_commitment  5050 non-null   int64
#  9   personal_status         5050 non-null   object
#  10  other_parties           5050 non-null   object
#  11  residence_since         5050 non-null   int64
#  12  property_magnitude      5050 non-null   object
#  13  age                     5050 non-null   int64
# ...

# %%
X = df[['duration', 'credit_amount', 'installment_commitment', 'residence_since', 'age', 'other_payment_plans', 'bureau_score', 'num_dependents', 'own_telephone', 'foreign_worker', 'Spend_debit_card']]

Y = df[['class']]

# %%
X.head(5)
# Out:
#    duration  credit_amount  installment_commitment  residence_since  age  \
# 0        19            640                       1                1   22
# 1        60            903                       2                2   25
# 2        72            523                       2                2   24
# 3        55            605                       2                4   30
# 4        67            709                       2                3   30
#
#    other_payment_plans  bureau_score  num_dependents  own_telephone  \
# 0                    1           110               9              1
# 1                    2           400               3              0
# 2                    2           190              13              0
# 3                    0           320               1              0
# 4                    1           170               4              1
#
#    foreign_worker  Spend_debit_card
# 0               0              3463
# 1               1              1048
# ...

# %%
Y.head(5)
# Out:
#    class
# 0      0
# 1      1
# 2      0
# 3      0
# 4      0

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,Y,test_size=0.33,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier
# Out:
# LogisticRegression()

# %%
from sklearn.model_selection import GridSearchCV
parameter = {'penalty':['l1', 'l2', 'elasticnet'],'C':[0.01,2,3,4,6],'max_iter':[100,200,300]}

logistic_regressor = GridSearchCV(classifier,param_grid=parameter,scoring='accuracy',cv=10)

logistic_regressor.fit(X_train,y_train)
# Out:
# C:\Users\Dell\.conda\envs\Machine Learning\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Dell\.conda\envs\Machine Learning\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# ...

# %%
logistic_regressor.best_params_
# Out:
# {'C': 2, 'max_iter': 100, 'penalty': 'l2'}

# %%
logistic_regressor.best_score_
# Out:
# 0.630505664065909

# %%
y_pred = logistic_regressor.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.03      0.37      0.05        46
#            1       0.97      0.63      0.77      1621
#
#     accuracy                           0.63      1667
#    macro avg       0.50      0.50      0.41      1667
# weighted avg       0.95      0.63      0.75      1667

# %%
cm = confusion_matrix(y_pred,y_test)

plt.figure(figsize = (10,7))
sns.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
score = logistic_regressor.score(X_test,y_test)
score
# Out:
# 0.6262747450509898

# %% [markdown]
# ### Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
X_train, X_test, y_train, y_test = train_test_split(X,Y,test_size=0.33,random_state=42)

treeclass = RandomForestClassifier(n_estimators=500,
                                  random_state = 42)
treeclass.fit(X_train, y_train)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_18364\2122493688.py:5: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   treeclass.fit(X_train, y_train)
# RandomForestClassifier(n_estimators=500, random_state=42)

# %%
y_pred1 = treeclass.predict(X_test)
y_pred_prob = treeclass.predict_proba(X_test)
accuracy = treeclass.score(X_test, y_test)
accuracy
# Out:
# 0.6112777444511098

# %%
cm = confusion_matrix(y_pred1,y_test)

plt.figure(figsize = (10,7))
sns.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
score1 = accuracy_score(y_test,y_pred1)
score1
# Out:
# 0.6112777444511098

# %%
print(classification_report(y_pred1,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.12      0.40      0.18       181
#            1       0.90      0.64      0.75      1486
#
#     accuracy                           0.61      1667
#    macro avg       0.51      0.52      0.46      1667
# weighted avg       0.81      0.61      0.68      1667

# %% [markdown]
# ### Comparison Logistic Regression Model and Random Forest model

# %%
x = ['Logistic Regresion Model Accuracy','Random Forest Model Accuracy']
y = [score,score1]
plt.figure(1,figsize=(10,8))
plt.bar(x,y,color ='maroon')
plt.title('Comparison Logistic Regression Model and Random Forest model',fontsize=14)
plt.xlabel('Model Name',fontsize=12)
plt.ylabel('Accuracy',fontsize=12)
plt.show()
